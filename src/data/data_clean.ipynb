# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel("data.xlsx",sheet_name="GSI 2023 summary data")
df
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 0    Source: Walk Free 2023, Global Slavery Index 2...         NaN
# 1                                              Country  Population
# 2                                          Afghanistan    38928000
# 3                                              Albania     2878000
# 4                                              Algeria    43851000
# ..                                                 ...         ...
# 177                                          Venezuela    28436000
# 178                                           Viet Nam    97339000
# 179                                              Yemen    29826000
# 180                                             Zambia    18384000
# 181                                           Zimbabwe    14863000
#
#                   Unnamed: 2  \
# 0                        NaN
# 1                     Region
# 2       Asia and the Pacific
# 3    Europe and Central Asia
# ...

# %% [markdown]
# REMOVING DUPLICATES

# %%
df.drop_duplicates()
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 0    Source: Walk Free 2023, Global Slavery Index 2...         NaN
# 1                                              Country  Population
# 2                                          Afghanistan    38928000
# 3                                              Albania     2878000
# 4                                              Algeria    43851000
# ..                                                 ...         ...
# 177                                          Venezuela    28436000
# 178                                           Viet Nam    97339000
# 179                                              Yemen    29826000
# 180                                             Zambia    18384000
# 181                                           Zimbabwe    14863000
#
#                   Unnamed: 2  \
# 0                        NaN
# 1                     Region
# 2       Asia and the Pacific
# 3    Europe and Central Asia
# ...

# %% [markdown]
# Removing extra rows on top

# %%
# Drop completely empty columns
df = df.dropna(axis=1, how='all')

# Remove the first two rows
df = df.iloc[1:].reset_index(drop=True)

# Set the new header row (previous row 3, now row 1)
df.columns = df.iloc[0]  # Assign new column names
df = df[1:].reset_index(drop=True)  # Remove the row used as headers

df
# Out:
# 0                Country Population                   Region  \
# 0            Afghanistan   38928000     Asia and the Pacific
# 1                Albania    2878000  Europe and Central Asia
# 2                Algeria   43851000                   Africa
# 3                 Angola   32866000                   Africa
# 4    Antigua and Barbuda      98000                 Americas
# ..                   ...        ...                      ...
# 175            Venezuela   28436000                 Americas
# 176             Viet Nam   97339000     Asia and the Pacific
# 177                Yemen   29826000              Arab States
# 178               Zambia   18384000                   Africa
# 179             Zimbabwe   14863000                   Africa
#
# 0   Estimated prevalence of modern slavery per 1,000 population  \
# 0                                            12.959972
# 1                                            11.813945
# ...

# %%
df = df[['Country',
         'Population', 
         'Region',
         'Estimated prevalence of modern slavery per 1,000 population',
         'Estimated number of people in modern slavery',
         'Governance issues',
         'Effects of conflict',
         'Total Vulnerability score (%)',
         'Risk factors, such as attitudes, social systems, and institutions that enable modern slavery are addressed (%)',
         'Government response total (%)',
        "Survivors of slavery are identified and supported to exit and remain out of modern slavery (%)"    # Victim support metric
         ]]
df
# Out:
# 0                Country Population                   Region  \
# 0            Afghanistan   38928000     Asia and the Pacific
# 1                Albania    2878000  Europe and Central Asia
# 2                Algeria   43851000                   Africa
# 3                 Angola   32866000                   Africa
# 4    Antigua and Barbuda      98000                 Americas
# ..                   ...        ...                      ...
# 175            Venezuela   28436000                 Americas
# 176             Viet Nam   97339000     Asia and the Pacific
# 177                Yemen   29826000              Arab States
# 178               Zambia   18384000                   Africa
# 179             Zimbabwe   14863000                   Africa
#
# 0   Estimated prevalence of modern slavery per 1,000 population  \
# 0                                            12.959972
# 1                                            11.813945
# ...

# %%
for x in df.index:
    if df.loc[x,'Total Vulnerability score (%)'] == 'NaN'  or df.loc[x,'Government response total (%)'] == 'N/A':
        df.drop(x, inplace=True)
df.reset_index()
df
# Out:
# 0                Country Population                   Region  \
# 0            Afghanistan   38928000     Asia and the Pacific
# 1                Albania    2878000  Europe and Central Asia
# 2                Algeria   43851000                   Africa
# 3                 Angola   32866000                   Africa
# 4    Antigua and Barbuda      98000                 Americas
# ..                   ...        ...                      ...
# 175            Venezuela   28436000                 Americas
# 176             Viet Nam   97339000     Asia and the Pacific
# 177                Yemen   29826000              Arab States
# 178               Zambia   18384000                   Africa
# 179             Zimbabwe   14863000                   Africa
#
# 0   Estimated prevalence of modern slavery per 1,000 population  \
# 0                                            12.959972
# 1                                            11.813945
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)
